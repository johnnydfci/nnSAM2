# %%
from PIL import Image
import os, glob
import SimpleITK as sitk
import numpy as np

data_dir = 'videos/CT_word'
# data_dir = 'videos/CT_TT'

img_nii_dir = os.path.join(data_dir, 'data_in_nii/img_in_nii_L4L5')
seg_nii_dir = os.path.join(data_dir, 'data_in_nii/label_in_nii_L4L5_2class')

data_jpg_dir = 'data_in_jpg_2class'
img_png_dir = os.path.join(data_dir, data_jpg_dir , 'img_in_jpg')
seg_png_dir = os.path.join(data_dir, data_jpg_dir , 'label_in_png')


os.makedirs(img_png_dir, exist_ok=True)
os.makedirs(seg_png_dir, exist_ok=True)

class_num = 2
size = (256, 256)  # 目标尺寸 (宽, 高)
multiply = int(200 / class_num)  # 颜色放大因子

img_nii_files = sorted(glob.glob(os.path.join(img_nii_dir, '*.nii.gz')))

for img_path in img_nii_files:
    pid = os.path.basename(img_path).replace('_img.nii.gz', '')
    # pid = pid.replace('img.nii.gz', '')
    seg_files = glob.glob(os.path.join(seg_nii_dir, pid + '*.nii.gz'))
    if not seg_files:
        print(f"⚠️ Segmentation not found for {pid}, skip")
        continue
    seg_path = seg_files[0]

    img_array = sitk.GetArrayFromImage(sitk.ReadImage(img_path))
    seg_array = sitk.GetArrayFromImage(sitk.ReadImage(seg_path))

    lb, ub = np.percentile(img_array, [0.5, 99.5])
    img_array = np.clip(img_array, lb, ub)
    img_norm = ((img_array - lb) / (ub - lb) * 255).astype(np.uint8)

    img_pid_dir = os.path.join(img_png_dir, pid)
    seg_pid_dir = os.path.join(seg_png_dir, pid)
    os.makedirs(img_pid_dir, exist_ok=True)
    os.makedirs(seg_pid_dir, exist_ok=True)

    for i in range(img_norm.shape[0]):
        rotate = 'ID' in pid or pid.startswith('s')
        img_slice = np.rot90(img_norm[i], 2) if rotate else img_norm[i]
        seg_slice = np.rot90(seg_array[i], 2) if rotate else seg_array[i]


        if class_num == 2 and 'CT' not in data_dir:
            seg_mapped = np.zeros_like(seg_slice, dtype=np.uint8)
            seg_mapped[np.isin(seg_slice, [1, 2])] = 1
            seg_mapped[np.isin(seg_slice, [3, 4])] = 2

        else:
            seg_mapped = seg_slice.astype(np.uint8)

        # 统一resize，不分类别
        img_pil = Image.fromarray(img_slice).resize(size, resample=Image.BILINEAR)
        seg_pil = Image.fromarray((seg_mapped * multiply).astype(np.uint8)).resize(size, resample=Image.NEAREST)

        img_output_path = os.path.join(img_pid_dir, f'{pid}_slice_{i:03d}_img.jpg')
        seg_output_path = os.path.join(seg_pid_dir, f'{pid}_slice_{i:03d}_seg.png')

        img_pil.save(img_output_path)
        seg_pil.save(seg_output_path)

        print(f"✅ Saved slice {i} for {pid}")

print("✅ All done!")
# Out:
# ✅ Saved slice 0 for word_0002_L4L5
# ✅ Saved slice 1 for word_0002_L4L5
# ✅ Saved slice 2 for word_0002_L4L5
# ✅ Saved slice 3 for word_0002_L4L5
# ✅ Saved slice 4 for word_0002_L4L5
# ✅ Saved slice 5 for word_0002_L4L5
# ✅ Saved slice 6 for word_0002_L4L5
# ✅ Saved slice 7 for word_0002_L4L5
# ✅ Saved slice 8 for word_0002_L4L5
# ✅ Saved slice 9 for word_0002_L4L5
# ✅ Saved slice 10 for word_0002_L4L5
# ✅ Saved slice 11 for word_0002_L4L5
# ✅ Saved slice 12 for word_0002_L4L5
# ✅ Saved slice 13 for word_0002_L4L5
# ✅ Saved slice 14 for word_0002_L4L5
# ✅ Saved slice 0 for word_0003_L4L5
# ✅ Saved slice 1 for word_0003_L4L5
# ✅ Saved slice 2 for word_0003_L4L5
# ✅ Saved slice 3 for word_0003_L4L5
# ✅ Saved slice 4 for word_0003_L4L5
# ✅ Saved slice 5 for word_0003_L4L5
# ✅ Saved slice 6 for word_0003_L4L5
# ✅ Saved slice 7 for word_0003_L4L5
# ✅ Saved slice 8 for word_0003_L4L5
# ✅ Saved slice 9 for word_0003_L4L5
# ✅ Saved slice 10 for word_0003_L4L5
# ✅ Saved slice 11 for word_0003_L4L5
# ✅ Saved slice 0 for word_0004_L4L5
# ✅ Saved slice 1 for word_0004_L4L5
# ✅ Saved slice 2 for word_0004_L4L5
# ✅ Saved slice 3 for word_0004_L4L5
# ✅ Saved slice 4 for word_0004_L4L5
# ✅ Saved slice 5 for word_0004_L4L5
# ✅ Saved slice 6 for word_0004_L4L5
# ✅ Saved slice 7 for word_0004_L4L5
# ✅ Saved slice 8 for word_0004_L4L5
# ✅ Saved slice 9 for word_0004_L4L5
# ✅ Saved slice 10 for word_0004_L4L5
# ✅ Saved slice 11 for word_0004_L4L5
# ✅ Saved slice 0 for word_0005_L4L5
# ✅ Saved slice 1 for word_0005_L4L5
# ✅ Saved slice 2 for word_0005_L4L5
# ✅ Saved slice 3 for word_0005_L4L5
# ✅ Saved slice 4 for word_0005_L4L5
# ✅ Saved slice 5 for word_0005_L4L5
# ✅ Saved slice 6 for word_0005_L4L5
# ✅ Saved slice 7 for word_0005_L4L5
# ✅ Saved slice 8 for word_0005_L4L5
# ✅ Saved slice 9 for word_0005_L4L5
# ✅ Saved slice 10 for word_0005_L4L5
# ✅ Saved slice 0 for word_0006_L4L5
# ✅ Saved slice 1 for word_0006_L4L5
# ✅ Saved slice 2 for word_0006_L4L5
# ✅ Saved slice 3 for word_0006_L4L5
# ✅ Saved slice 4 for word_0006_L4L5
# ✅ Saved slice 5 for word_0006_L4L5
# ✅ Saved slice 6 for word_0006_L4L5
# ✅ Saved slice 7 for word_0006_L4L5
# ✅ Saved slice 8 for word_0006_L4L5
# ✅ Saved slice 9 for word_0006_L4L5
# ✅ Saved slice 10 for word_0006_L4L5
# ✅ Saved slice 11 for word_0006_L4L5
# ✅ Saved slice 12 for word_0006_L4L5
# ✅ Saved slice 0 for word_0008_L4L5
# ✅ Saved slice 1 for word_0008_L4L5
# ✅ Saved slice 2 for word_0008_L4L5
# ✅ Saved slice 3 for word_0008_L4L5
# ✅ Saved slice 4 for word_0008_L4L5
# ✅ Saved slice 5 for word_0008_L4L5
# ✅ Saved slice 6 for word_0008_L4L5
# ✅ Saved slice 7 for word_0008_L4L5
# ✅ Saved slice 8 for word_0008_L4L5
# ✅ Saved slice 9 for word_0008_L4L5
# ✅ Saved slice 0 for word_0009_L4L5
# ✅ Saved slice 1 for word_0009_L4L5
# ✅ Saved slice 2 for word_0009_L4L5
# ✅ Saved slice 3 for word_0009_L4L5
# ✅ Saved slice 4 for word_0009_L4L5
# ✅ Saved slice 5 for word_0009_L4L5
# ✅ Saved slice 6 for word_0009_L4L5
# ✅ Saved slice 7 for word_0009_L4L5
# ✅ Saved slice 8 for word_0009_L4L5
# ✅ Saved slice 9 for word_0009_L4L5
# ✅ Saved slice 10 for word_0009_L4L5
# ✅ Saved slice 11 for word_0009_L4L5
# ✅ Saved slice 12 for word_0009_L4L5
# ✅ Saved slice 13 for word_0009_L4L5
# ✅ Saved slice 0 for word_0010_L4L5
# ✅ Saved slice 1 for word_0010_L4L5
# ✅ Saved slice 2 for word_0010_L4L5
# ✅ Saved slice 3 for word_0010_L4L5
# ✅ Saved slice 4 for word_0010_L4L5
# ✅ Saved slice 5 for word_0010_L4L5
# ✅ Saved slice 6 for word_0010_L4L5
# ✅ Saved slice 7 for word_0010_L4L5
# ✅ Saved slice 8 for word_0010_L4L5
# ✅ Saved slice 9 for word_0010_L4L5
# ✅ Saved slice 10 for word_0010_L4L5
# ✅ Saved slice 0 for word_0011_L4L5
# ✅ Saved slice 1 for word_0011_L4L5
# ✅ Saved slice 2 for word_0011_L4L5
# ✅ Saved slice 3 for word_0011_L4L5
# ✅ Saved slice 4 for word_0011_L4L5
# ✅ Saved slice 5 for word_0011_L4L5
# ✅ Saved slice 6 for word_0011_L4L5
# ✅ Saved slice 7 for word_0011_L4L5
# ✅ Saved slice 8 for word_0011_L4L5
# ✅ Saved slice 9 for word_0011_L4L5
# ✅ Saved slice 10 for word_0011_L4L5
# ✅ Saved slice 11 for word_0011_L4L5
# ✅ Saved slice 0 for word_0012_L4L5
# ✅ Saved slice 1 for word_0012_L4L5
# ✅ Saved slice 2 for word_0012_L4L5
# ✅ Saved slice 3 for word_0012_L4L5
# ✅ Saved slice 4 for word_0012_L4L5
# ✅ Saved slice 5 for word_0012_L4L5
# ✅ Saved slice 6 for word_0012_L4L5
# ✅ Saved slice 7 for word_0012_L4L5
# ✅ Saved slice 8 for word_0012_L4L5
# ✅ Saved slice 9 for word_0012_L4L5
# ✅ Saved slice 10 for word_0012_L4L5
# ✅ Saved slice 11 for word_0012_L4L5
# ✅ Saved slice 12 for word_0012_L4L5
# ✅ Saved slice 0 for word_0013_L4L5
# ✅ Saved slice 1 for word_0013_L4L5
# ✅ Saved slice 2 for word_0013_L4L5
# ✅ Saved slice 3 for word_0013_L4L5
# ✅ Saved slice 4 for word_0013_L4L5
# ✅ Saved slice 5 for word_0013_L4L5
# ✅ Saved slice 6 for word_0013_L4L5
# ✅ Saved slice 7 for word_0013_L4L5
# ✅ Saved slice 8 for word_0013_L4L5
# ✅ Saved slice 9 for word_0013_L4L5
# ✅ Saved slice 10 for word_0013_L4L5
# ✅ Saved slice 11 for word_0013_L4L5
# ✅ Saved slice 12 for word_0013_L4L5
# ✅ Saved slice 0 for word_0018_L4L5
# ✅ Saved slice 1 for word_0018_L4L5
# ✅ Saved slice 2 for word_0018_L4L5
# ✅ Saved slice 3 for word_0018_L4L5
# ✅ Saved slice 4 for word_0018_L4L5
# ✅ Saved slice 5 for word_0018_L4L5
# ✅ Saved slice 6 for word_0018_L4L5
# ✅ Saved slice 7 for word_0018_L4L5
# ✅ Saved slice 8 for word_0018_L4L5
# ✅ Saved slice 9 for word_0018_L4L5
# ✅ Saved slice 10 for word_0018_L4L5
# ✅ Saved slice 11 for word_0018_L4L5
# ✅ Saved slice 0 for word_0020_L4L5
# ✅ Saved slice 1 for word_0020_L4L5
# ✅ Saved slice 2 for word_0020_L4L5
# ✅ Saved slice 3 for word_0020_L4L5
# ✅ Saved slice 4 for word_0020_L4L5
# ✅ Saved slice 5 for word_0020_L4L5
# ✅ Saved slice 6 for word_0020_L4L5
# ✅ Saved slice 7 for word_0020_L4L5
# ✅ Saved slice 8 for word_0020_L4L5
# ✅ Saved slice 9 for word_0020_L4L5
# ✅ Saved slice 10 for word_0020_L4L5
# ✅ Saved slice 11 for word_0020_L4L5
# ✅ Saved slice 0 for word_0022_L4L5
# ✅ Saved slice 1 for word_0022_L4L5
# ✅ Saved slice 2 for word_0022_L4L5
# ✅ Saved slice 3 for word_0022_L4L5
# ✅ Saved slice 4 for word_0022_L4L5
# ✅ Saved slice 5 for word_0022_L4L5
# ✅ Saved slice 6 for word_0022_L4L5
# ✅ Saved slice 7 for word_0022_L4L5
# ✅ Saved slice 8 for word_0022_L4L5
# ✅ Saved slice 9 for word_0022_L4L5
# ✅ Saved slice 10 for word_0022_L4L5
# ✅ Saved slice 11 for word_0022_L4L5
# ✅ Saved slice 12 for word_0022_L4L5
# ✅ Saved slice 0 for word_0026_L4L5
# ✅ Saved slice 1 for word_0026_L4L5
# ✅ Saved slice 2 for word_0026_L4L5
# ✅ Saved slice 3 for word_0026_L4L5
# ✅ Saved slice 4 for word_0026_L4L5
# ✅ Saved slice 5 for word_0026_L4L5
# ✅ Saved slice 6 for word_0026_L4L5
# ✅ Saved slice 7 for word_0026_L4L5
# ✅ Saved slice 8 for word_0026_L4L5
# ✅ Saved slice 9 for word_0026_L4L5
# ✅ Saved slice 10 for word_0026_L4L5
# ✅ Saved slice 11 for word_0026_L4L5
# ✅ Saved slice 12 for word_0026_L4L5
# ✅ Saved slice 0 for word_0027_L4L5
# ✅ Saved slice 1 for word_0027_L4L5
# ✅ Saved slice 2 for word_0027_L4L5
# ✅ Saved slice 3 for word_0027_L4L5
# ✅ Saved slice 4 for word_0027_L4L5
# ✅ Saved slice 5 for word_0027_L4L5
# ✅ Saved slice 6 for word_0027_L4L5
# ✅ Saved slice 7 for word_0027_L4L5
# ✅ Saved slice 8 for word_0027_L4L5
# ✅ Saved slice 9 for word_0027_L4L5
# ✅ Saved slice 10 for word_0027_L4L5
# ✅ Saved slice 0 for word_0028_L4L5
# ✅ Saved slice 1 for word_0028_L4L5
# ✅ Saved slice 2 for word_0028_L4L5
# ✅ Saved slice 3 for word_0028_L4L5
# ✅ Saved slice 4 for word_0028_L4L5
# ✅ Saved slice 5 for word_0028_L4L5
# ✅ Saved slice 6 for word_0028_L4L5
# ✅ Saved slice 7 for word_0028_L4L5
# ✅ Saved slice 8 for word_0028_L4L5
# ✅ Saved slice 9 for word_0028_L4L5
# ✅ Saved slice 10 for word_0028_L4L5
# ✅ Saved slice 11 for word_0028_L4L5
# ✅ Saved slice 12 for word_0028_L4L5
# ✅ Saved slice 0 for word_0029_L4L5
# ✅ Saved slice 1 for word_0029_L4L5
# ✅ Saved slice 2 for word_0029_L4L5
# ✅ Saved slice 3 for word_0029_L4L5
# ✅ Saved slice 4 for word_0029_L4L5
# ✅ Saved slice 5 for word_0029_L4L5
# ✅ Saved slice 6 for word_0029_L4L5
# ✅ Saved slice 7 for word_0029_L4L5
# ✅ Saved slice 8 for word_0029_L4L5
# ✅ Saved slice 9 for word_0029_L4L5
# ✅ Saved slice 10 for word_0029_L4L5
# ✅ Saved slice 0 for word_0030_L4L5
# ✅ Saved slice 1 for word_0030_L4L5
# ✅ Saved slice 2 for word_0030_L4L5
# ✅ Saved slice 3 for word_0030_L4L5
# ✅ Saved slice 4 for word_0030_L4L5
# ✅ Saved slice 5 for word_0030_L4L5
# ✅ Saved slice 6 for word_0030_L4L5
# ✅ Saved slice 7 for word_0030_L4L5
# ✅ Saved slice 8 for word_0030_L4L5
# ✅ Saved slice 9 for word_0030_L4L5
# ✅ Saved slice 10 for word_0030_L4L5
# ✅ Saved slice 11 for word_0030_L4L5
# ✅ Saved slice 12 for word_0030_L4L5
# ✅ Saved slice 0 for word_0032_L4L5
# ✅ Saved slice 1 for word_0032_L4L5
# ✅ Saved slice 2 for word_0032_L4L5
# ✅ Saved slice 3 for word_0032_L4L5
# ✅ Saved slice 4 for word_0032_L4L5
# ✅ Saved slice 5 for word_0032_L4L5
# ✅ Saved slice 6 for word_0032_L4L5
# ✅ Saved slice 7 for word_0032_L4L5
# ✅ Saved slice 8 for word_0032_L4L5
# ✅ Saved slice 9 for word_0032_L4L5
# ✅ Saved slice 10 for word_0032_L4L5
# ✅ Saved slice 11 for word_0032_L4L5
# ✅ Saved slice 0 for word_0036_L4L5
# ✅ Saved slice 1 for word_0036_L4L5
# ✅ Saved slice 2 for word_0036_L4L5
# ✅ Saved slice 3 for word_0036_L4L5
# ✅ Saved slice 4 for word_0036_L4L5
# ✅ Saved slice 5 for word_0036_L4L5
# ✅ Saved slice 6 for word_0036_L4L5
# ✅ Saved slice 7 for word_0036_L4L5
# ✅ Saved slice 8 for word_0036_L4L5
# ✅ Saved slice 9 for word_0036_L4L5
# ✅ Saved slice 10 for word_0036_L4L5
# ✅ Saved slice 11 for word_0036_L4L5
# ✅ Saved slice 12 for word_0036_L4L5
# ✅ Saved slice 0 for word_0038_L4L5
# ✅ Saved slice 1 for word_0038_L4L5
# ✅ Saved slice 2 for word_0038_L4L5
# ✅ Saved slice 3 for word_0038_L4L5
# ✅ Saved slice 4 for word_0038_L4L5
# ✅ Saved slice 5 for word_0038_L4L5
# ✅ Saved slice 6 for word_0038_L4L5
# ✅ Saved slice 7 for word_0038_L4L5
# ✅ Saved slice 8 for word_0038_L4L5
# ✅ Saved slice 9 for word_0038_L4L5
# ✅ Saved slice 10 for word_0038_L4L5
# ✅ Saved slice 11 for word_0038_L4L5
# ✅ Saved slice 12 for word_0038_L4L5
# ✅ Saved slice 0 for word_0040_L4L5
# ✅ Saved slice 1 for word_0040_L4L5
# ✅ Saved slice 2 for word_0040_L4L5
# ✅ Saved slice 3 for word_0040_L4L5
# ✅ Saved slice 4 for word_0040_L4L5
# ✅ Saved slice 5 for word_0040_L4L5
# ✅ Saved slice 6 for word_0040_L4L5
# ✅ Saved slice 7 for word_0040_L4L5
# ✅ Saved slice 8 for word_0040_L4L5
# ✅ Saved slice 9 for word_0040_L4L5
# ✅ Saved slice 10 for word_0040_L4L5
# ✅ Saved slice 11 for word_0040_L4L5
# ✅ Saved slice 0 for word_0041_L4L5
# ✅ Saved slice 1 for word_0041_L4L5
# ✅ Saved slice 2 for word_0041_L4L5
# ✅ Saved slice 3 for word_0041_L4L5
# ✅ Saved slice 4 for word_0041_L4L5
# ✅ Saved slice 5 for word_0041_L4L5
# ✅ Saved slice 6 for word_0041_L4L5
# ✅ Saved slice 7 for word_0041_L4L5
# ✅ Saved slice 8 for word_0041_L4L5
# ✅ Saved slice 9 for word_0041_L4L5
# ✅ Saved slice 10 for word_0041_L4L5
# ✅ Saved slice 11 for word_0041_L4L5
# ✅ Saved slice 0 for word_0042_L4L5
# ✅ Saved slice 1 for word_0042_L4L5
# ✅ Saved slice 2 for word_0042_L4L5
# ✅ Saved slice 3 for word_0042_L4L5
# ✅ Saved slice 4 for word_0042_L4L5
# ✅ Saved slice 5 for word_0042_L4L5
# ✅ Saved slice 6 for word_0042_L4L5
# ✅ Saved slice 7 for word_0042_L4L5
# ✅ Saved slice 8 for word_0042_L4L5
# ✅ Saved slice 9 for word_0042_L4L5
# ✅ Saved slice 10 for word_0042_L4L5
# ✅ Saved slice 11 for word_0042_L4L5
# ✅ Saved slice 12 for word_0042_L4L5
# ✅ Saved slice 0 for word_0044_L4L5
# ✅ Saved slice 1 for word_0044_L4L5
# ✅ Saved slice 2 for word_0044_L4L5
# ✅ Saved slice 3 for word_0044_L4L5
# ✅ Saved slice 4 for word_0044_L4L5
# ✅ Saved slice 5 for word_0044_L4L5
# ✅ Saved slice 6 for word_0044_L4L5
# ✅ Saved slice 7 for word_0044_L4L5
# ✅ Saved slice 8 for word_0044_L4L5
# ✅ Saved slice 9 for word_0044_L4L5
# ✅ Saved slice 10 for word_0044_L4L5
# ✅ Saved slice 0 for word_0046_L4L5
# ✅ Saved slice 1 for word_0046_L4L5
# ✅ Saved slice 2 for word_0046_L4L5
# ✅ Saved slice 3 for word_0046_L4L5
# ✅ Saved slice 4 for word_0046_L4L5
# ✅ Saved slice 5 for word_0046_L4L5
# ✅ Saved slice 6 for word_0046_L4L5
# ✅ Saved slice 7 for word_0046_L4L5
# ✅ Saved slice 8 for word_0046_L4L5
# ✅ Saved slice 9 for word_0046_L4L5
# ✅ Saved slice 10 for word_0046_L4L5
# ✅ Saved slice 11 for word_0046_L4L5
# ✅ Saved slice 12 for word_0046_L4L5
# ✅ Saved slice 0 for word_0047_L4L5
# ✅ Saved slice 1 for word_0047_L4L5
# ✅ Saved slice 2 for word_0047_L4L5
# ✅ Saved slice 3 for word_0047_L4L5
# ✅ Saved slice 4 for word_0047_L4L5
# ✅ Saved slice 5 for word_0047_L4L5
# ✅ Saved slice 6 for word_0047_L4L5
# ✅ Saved slice 7 for word_0047_L4L5
# ✅ Saved slice 8 for word_0047_L4L5
# ✅ Saved slice 9 for word_0047_L4L5
# ✅ Saved slice 10 for word_0047_L4L5
# ✅ Saved slice 11 for word_0047_L4L5
# ✅ Saved slice 0 for word_0049_L4L5
# ✅ Saved slice 1 for word_0049_L4L5
# ✅ Saved slice 2 for word_0049_L4L5
# ✅ Saved slice 3 for word_0049_L4L5
# ✅ Saved slice 4 for word_0049_L4L5
# ✅ Saved slice 5 for word_0049_L4L5
# ✅ Saved slice 6 for word_0049_L4L5
# ✅ Saved slice 7 for word_0049_L4L5
# ✅ Saved slice 8 for word_0049_L4L5
# ✅ Saved slice 9 for word_0049_L4L5
# ✅ Saved slice 10 for word_0049_L4L5
# ✅ Saved slice 11 for word_0049_L4L5
# ✅ Saved slice 0 for word_0051_L4L5
# ✅ Saved slice 1 for word_0051_L4L5
# ✅ Saved slice 2 for word_0051_L4L5
# ✅ Saved slice 3 for word_0051_L4L5
# ✅ Saved slice 4 for word_0051_L4L5
# ✅ Saved slice 5 for word_0051_L4L5
# ✅ Saved slice 6 for word_0051_L4L5
# ✅ Saved slice 7 for word_0051_L4L5
# ✅ Saved slice 8 for word_0051_L4L5
# ✅ Saved slice 9 for word_0051_L4L5
# ✅ Saved slice 0 for word_0053_L4L5
# ✅ Saved slice 1 for word_0053_L4L5
# ✅ Saved slice 2 for word_0053_L4L5
# ✅ Saved slice 3 for word_0053_L4L5
# ✅ Saved slice 4 for word_0053_L4L5
# ✅ Saved slice 5 for word_0053_L4L5
# ✅ Saved slice 6 for word_0053_L4L5
# ✅ Saved slice 7 for word_0053_L4L5
# ✅ Saved slice 8 for word_0053_L4L5
# ✅ Saved slice 9 for word_0053_L4L5
# ✅ Saved slice 10 for word_0053_L4L5
# ✅ Saved slice 0 for word_0055_L4L5
# ✅ Saved slice 1 for word_0055_L4L5
# ✅ Saved slice 2 for word_0055_L4L5
# ✅ Saved slice 3 for word_0055_L4L5
# ✅ Saved slice 4 for word_0055_L4L5
# ✅ Saved slice 5 for word_0055_L4L5
# ✅ Saved slice 6 for word_0055_L4L5
# ✅ Saved slice 7 for word_0055_L4L5
# ✅ Saved slice 8 for word_0055_L4L5
# ✅ Saved slice 9 for word_0055_L4L5
# ✅ Saved slice 10 for word_0055_L4L5
# ✅ Saved slice 0 for word_0056_L4L5
# ✅ Saved slice 1 for word_0056_L4L5
# ✅ Saved slice 2 for word_0056_L4L5
# ✅ Saved slice 3 for word_0056_L4L5
# ✅ Saved slice 4 for word_0056_L4L5
# ✅ Saved slice 5 for word_0056_L4L5
# ✅ Saved slice 6 for word_0056_L4L5
# ✅ Saved slice 7 for word_0056_L4L5
# ✅ Saved slice 8 for word_0056_L4L5
# ✅ Saved slice 9 for word_0056_L4L5
# ✅ Saved slice 10 for word_0056_L4L5
# ✅ Saved slice 11 for word_0056_L4L5
# ✅ Saved slice 12 for word_0056_L4L5
# ✅ Saved slice 0 for word_0058_L4L5
# ✅ Saved slice 1 for word_0058_L4L5
# ✅ Saved slice 2 for word_0058_L4L5
# ✅ Saved slice 3 for word_0058_L4L5
# ✅ Saved slice 4 for word_0058_L4L5
# ✅ Saved slice 5 for word_0058_L4L5
# ✅ Saved slice 6 for word_0058_L4L5
# ✅ Saved slice 7 for word_0058_L4L5
# ✅ Saved slice 8 for word_0058_L4L5
# ✅ Saved slice 9 for word_0058_L4L5
# ✅ Saved slice 10 for word_0058_L4L5
# ✅ Saved slice 0 for word_0059_L4L5
# ✅ Saved slice 1 for word_0059_L4L5
# ✅ Saved slice 2 for word_0059_L4L5
# ✅ Saved slice 3 for word_0059_L4L5
# ✅ Saved slice 4 for word_0059_L4L5
# ✅ Saved slice 5 for word_0059_L4L5
# ✅ Saved slice 6 for word_0059_L4L5
# ✅ Saved slice 7 for word_0059_L4L5
# ✅ Saved slice 8 for word_0059_L4L5
# ✅ Saved slice 9 for word_0059_L4L5
# ✅ Saved slice 10 for word_0059_L4L5
# ✅ Saved slice 0 for word_0061_L4L5
# ✅ Saved slice 1 for word_0061_L4L5
# ✅ Saved slice 2 for word_0061_L4L5
# ✅ Saved slice 3 for word_0061_L4L5
# ✅ Saved slice 4 for word_0061_L4L5
# ✅ Saved slice 5 for word_0061_L4L5
# ✅ Saved slice 6 for word_0061_L4L5
# ✅ Saved slice 7 for word_0061_L4L5
# ✅ Saved slice 8 for word_0061_L4L5
# ✅ Saved slice 9 for word_0061_L4L5
# ✅ Saved slice 10 for word_0061_L4L5
# ✅ Saved slice 11 for word_0061_L4L5
# ✅ Saved slice 0 for word_0062_L4L5
# ✅ Saved slice 1 for word_0062_L4L5
# ✅ Saved slice 2 for word_0062_L4L5
# ✅ Saved slice 3 for word_0062_L4L5
# ✅ Saved slice 4 for word_0062_L4L5
# ✅ Saved slice 5 for word_0062_L4L5
# ✅ Saved slice 6 for word_0062_L4L5
# ✅ Saved slice 7 for word_0062_L4L5
# ✅ Saved slice 8 for word_0062_L4L5
# ✅ Saved slice 9 for word_0062_L4L5
# ✅ Saved slice 10 for word_0062_L4L5
# ✅ Saved slice 11 for word_0062_L4L5
# ✅ Saved slice 12 for word_0062_L4L5
# ✅ Saved slice 0 for word_0063_L4L5
# ✅ Saved slice 1 for word_0063_L4L5
# ✅ Saved slice 2 for word_0063_L4L5
# ✅ Saved slice 3 for word_0063_L4L5
# ✅ Saved slice 4 for word_0063_L4L5
# ✅ Saved slice 5 for word_0063_L4L5
# ✅ Saved slice 6 for word_0063_L4L5
# ✅ Saved slice 7 for word_0063_L4L5
# ✅ Saved slice 8 for word_0063_L4L5
# ✅ Saved slice 9 for word_0063_L4L5
# ✅ Saved slice 10 for word_0063_L4L5
# ✅ Saved slice 0 for word_0064_L4L5
# ✅ Saved slice 1 for word_0064_L4L5
# ✅ Saved slice 2 for word_0064_L4L5
# ✅ Saved slice 3 for word_0064_L4L5
# ✅ Saved slice 4 for word_0064_L4L5
# ✅ Saved slice 5 for word_0064_L4L5
# ✅ Saved slice 6 for word_0064_L4L5
# ✅ Saved slice 7 for word_0064_L4L5
# ✅ Saved slice 8 for word_0064_L4L5
# ✅ Saved slice 9 for word_0064_L4L5
# ✅ Saved slice 10 for word_0064_L4L5
# ✅ Saved slice 11 for word_0064_L4L5
# ✅ Saved slice 12 for word_0064_L4L5
# ✅ Saved slice 13 for word_0064_L4L5
# ✅ Saved slice 0 for word_0065_L4L5
# ✅ Saved slice 1 for word_0065_L4L5
# ✅ Saved slice 2 for word_0065_L4L5
# ✅ Saved slice 3 for word_0065_L4L5
# ✅ Saved slice 4 for word_0065_L4L5
# ✅ Saved slice 5 for word_0065_L4L5
# ✅ Saved slice 6 for word_0065_L4L5
# ✅ Saved slice 7 for word_0065_L4L5
# ✅ Saved slice 8 for word_0065_L4L5
# ✅ Saved slice 9 for word_0065_L4L5
# ✅ Saved slice 10 for word_0065_L4L5
# ✅ Saved slice 11 for word_0065_L4L5
# ✅ Saved slice 12 for word_0065_L4L5
# ✅ Saved slice 13 for word_0065_L4L5
# ✅ Saved slice 14 for word_0065_L4L5
# ✅ Saved slice 0 for word_0067_L4L5
# ✅ Saved slice 1 for word_0067_L4L5
# ✅ Saved slice 2 for word_0067_L4L5
# ✅ Saved slice 3 for word_0067_L4L5
# ✅ Saved slice 4 for word_0067_L4L5
# ✅ Saved slice 5 for word_0067_L4L5
# ✅ Saved slice 6 for word_0067_L4L5
# ✅ Saved slice 7 for word_0067_L4L5
# ✅ Saved slice 8 for word_0067_L4L5
# ✅ Saved slice 9 for word_0067_L4L5
# ✅ Saved slice 10 for word_0067_L4L5
# ✅ Saved slice 11 for word_0067_L4L5
# ✅ Saved slice 12 for word_0067_L4L5
# ✅ Saved slice 0 for word_0068_L4L5
# ✅ Saved slice 1 for word_0068_L4L5
# ✅ Saved slice 2 for word_0068_L4L5
# ✅ Saved slice 3 for word_0068_L4L5
# ✅ Saved slice 4 for word_0068_L4L5
# ✅ Saved slice 5 for word_0068_L4L5
# ✅ Saved slice 6 for word_0068_L4L5
# ✅ Saved slice 7 for word_0068_L4L5
# ✅ Saved slice 8 for word_0068_L4L5
# ✅ Saved slice 9 for word_0068_L4L5
# ✅ Saved slice 10 for word_0068_L4L5
# ✅ Saved slice 11 for word_0068_L4L5
# ✅ Saved slice 12 for word_0068_L4L5
# ✅ Saved slice 0 for word_0070_L4L5
# ✅ Saved slice 1 for word_0070_L4L5
# ✅ Saved slice 2 for word_0070_L4L5
# ✅ Saved slice 3 for word_0070_L4L5
# ✅ Saved slice 4 for word_0070_L4L5
# ✅ Saved slice 5 for word_0070_L4L5
# ✅ Saved slice 6 for word_0070_L4L5
# ✅ Saved slice 7 for word_0070_L4L5
# ✅ Saved slice 8 for word_0070_L4L5
# ✅ Saved slice 9 for word_0070_L4L5
# ✅ Saved slice 10 for word_0070_L4L5
# ✅ Saved slice 11 for word_0070_L4L5
# ✅ Saved slice 12 for word_0070_L4L5
# ✅ Saved slice 0 for word_0071_L4L5
# ✅ Saved slice 1 for word_0071_L4L5
# ✅ Saved slice 2 for word_0071_L4L5
# ✅ Saved slice 3 for word_0071_L4L5
# ✅ Saved slice 4 for word_0071_L4L5
# ✅ Saved slice 5 for word_0071_L4L5
# ✅ Saved slice 6 for word_0071_L4L5
# ✅ Saved slice 7 for word_0071_L4L5
# ✅ Saved slice 8 for word_0071_L4L5
# ✅ Saved slice 9 for word_0071_L4L5
# ✅ Saved slice 10 for word_0071_L4L5
# ✅ Saved slice 11 for word_0071_L4L5
# ✅ Saved slice 0 for word_0072_L4L5
# ✅ Saved slice 1 for word_0072_L4L5
# ✅ Saved slice 2 for word_0072_L4L5
# ✅ Saved slice 3 for word_0072_L4L5
# ✅ Saved slice 4 for word_0072_L4L5
# ✅ Saved slice 5 for word_0072_L4L5
# ✅ Saved slice 6 for word_0072_L4L5
# ✅ Saved slice 7 for word_0072_L4L5
# ✅ Saved slice 8 for word_0072_L4L5
# ✅ Saved slice 9 for word_0072_L4L5
# ✅ Saved slice 10 for word_0072_L4L5
# ✅ Saved slice 11 for word_0072_L4L5
# ✅ Saved slice 12 for word_0072_L4L5
# ✅ Saved slice 0 for word_0073_L4L5
# ✅ Saved slice 1 for word_0073_L4L5
# ✅ Saved slice 2 for word_0073_L4L5
# ✅ Saved slice 3 for word_0073_L4L5
# ✅ Saved slice 4 for word_0073_L4L5
# ✅ Saved slice 5 for word_0073_L4L5
# ✅ Saved slice 6 for word_0073_L4L5
# ✅ Saved slice 7 for word_0073_L4L5
# ✅ Saved slice 8 for word_0073_L4L5
# ✅ Saved slice 9 for word_0073_L4L5
# ✅ Saved slice 10 for word_0073_L4L5
# ✅ Saved slice 11 for word_0073_L4L5
# ✅ Saved slice 0 for word_0078_L4L5
# ✅ Saved slice 1 for word_0078_L4L5
# ✅ Saved slice 2 for word_0078_L4L5
# ✅ Saved slice 3 for word_0078_L4L5
# ✅ Saved slice 4 for word_0078_L4L5
# ✅ Saved slice 5 for word_0078_L4L5
# ✅ Saved slice 6 for word_0078_L4L5
# ✅ Saved slice 7 for word_0078_L4L5
# ✅ Saved slice 8 for word_0078_L4L5
# ✅ Saved slice 9 for word_0078_L4L5
# ✅ Saved slice 10 for word_0078_L4L5
# ✅ Saved slice 11 for word_0078_L4L5
# ✅ Saved slice 12 for word_0078_L4L5
# ✅ Saved slice 0 for word_0079_L4L5
# ✅ Saved slice 1 for word_0079_L4L5
# ✅ Saved slice 2 for word_0079_L4L5
# ✅ Saved slice 3 for word_0079_L4L5
# ✅ Saved slice 4 for word_0079_L4L5
# ✅ Saved slice 5 for word_0079_L4L5
# ✅ Saved slice 6 for word_0079_L4L5
# ✅ Saved slice 7 for word_0079_L4L5
# ✅ Saved slice 8 for word_0079_L4L5
# ✅ Saved slice 9 for word_0079_L4L5
# ✅ Saved slice 10 for word_0079_L4L5
# ✅ Saved slice 11 for word_0079_L4L5
# ✅ Saved slice 0 for word_0081_L4L5
# ✅ Saved slice 1 for word_0081_L4L5
# ✅ Saved slice 2 for word_0081_L4L5
# ✅ Saved slice 3 for word_0081_L4L5
# ✅ Saved slice 4 for word_0081_L4L5
# ✅ Saved slice 5 for word_0081_L4L5
# ✅ Saved slice 6 for word_0081_L4L5
# ✅ Saved slice 7 for word_0081_L4L5
# ✅ Saved slice 8 for word_0081_L4L5
# ✅ Saved slice 9 for word_0081_L4L5
# ✅ Saved slice 10 for word_0081_L4L5
# ✅ Saved slice 0 for word_0082_L4L5
# ✅ Saved slice 1 for word_0082_L4L5
# ✅ Saved slice 2 for word_0082_L4L5
# ✅ Saved slice 3 for word_0082_L4L5
# ✅ Saved slice 4 for word_0082_L4L5
# ✅ Saved slice 5 for word_0082_L4L5
# ✅ Saved slice 6 for word_0082_L4L5
# ✅ Saved slice 7 for word_0082_L4L5
# ✅ Saved slice 8 for word_0082_L4L5
# ✅ Saved slice 9 for word_0082_L4L5
# ✅ Saved slice 10 for word_0082_L4L5
# ✅ Saved slice 0 for word_0084_L4L5
# ✅ Saved slice 1 for word_0084_L4L5
# ✅ Saved slice 2 for word_0084_L4L5
# ✅ Saved slice 3 for word_0084_L4L5
# ✅ Saved slice 4 for word_0084_L4L5
# ✅ Saved slice 5 for word_0084_L4L5
# ✅ Saved slice 6 for word_0084_L4L5
# ✅ Saved slice 7 for word_0084_L4L5
# ✅ Saved slice 8 for word_0084_L4L5
# ✅ Saved slice 9 for word_0084_L4L5
# ✅ Saved slice 10 for word_0084_L4L5
# ✅ Saved slice 0 for word_0086_L4L5
# ✅ Saved slice 1 for word_0086_L4L5
# ✅ Saved slice 2 for word_0086_L4L5
# ✅ Saved slice 3 for word_0086_L4L5
# ✅ Saved slice 4 for word_0086_L4L5
# ✅ Saved slice 5 for word_0086_L4L5
# ✅ Saved slice 6 for word_0086_L4L5
# ✅ Saved slice 7 for word_0086_L4L5
# ✅ Saved slice 8 for word_0086_L4L5
# ✅ Saved slice 9 for word_0086_L4L5
# ✅ Saved slice 10 for word_0086_L4L5
# ✅ Saved slice 11 for word_0086_L4L5
# ✅ Saved slice 0 for word_0087_L4L5
# ✅ Saved slice 1 for word_0087_L4L5
# ✅ Saved slice 2 for word_0087_L4L5
# ✅ Saved slice 3 for word_0087_L4L5
# ✅ Saved slice 4 for word_0087_L4L5
# ✅ Saved slice 5 for word_0087_L4L5
# ✅ Saved slice 6 for word_0087_L4L5
# ✅ Saved slice 7 for word_0087_L4L5
# ✅ Saved slice 8 for word_0087_L4L5
# ✅ Saved slice 9 for word_0087_L4L5
# ✅ Saved slice 10 for word_0087_L4L5
# ✅ Saved slice 0 for word_0089_L4L5
# ✅ Saved slice 1 for word_0089_L4L5
# ✅ Saved slice 2 for word_0089_L4L5
# ✅ Saved slice 3 for word_0089_L4L5
# ✅ Saved slice 4 for word_0089_L4L5
# ✅ Saved slice 5 for word_0089_L4L5
# ✅ Saved slice 6 for word_0089_L4L5
# ✅ Saved slice 7 for word_0089_L4L5
# ✅ Saved slice 8 for word_0089_L4L5
# ✅ Saved slice 9 for word_0089_L4L5
# ✅ Saved slice 10 for word_0089_L4L5
# ✅ Saved slice 11 for word_0089_L4L5
# ✅ Saved slice 12 for word_0089_L4L5
# ✅ Saved slice 0 for word_0090_L4L5
# ✅ Saved slice 1 for word_0090_L4L5
# ✅ Saved slice 2 for word_0090_L4L5
# ✅ Saved slice 3 for word_0090_L4L5
# ✅ Saved slice 4 for word_0090_L4L5
# ✅ Saved slice 5 for word_0090_L4L5
# ✅ Saved slice 6 for word_0090_L4L5
# ✅ Saved slice 7 for word_0090_L4L5
# ✅ Saved slice 8 for word_0090_L4L5
# ✅ Saved slice 9 for word_0090_L4L5
# ✅ Saved slice 10 for word_0090_L4L5
# ✅ Saved slice 0 for word_0091_L4L5
# ✅ Saved slice 1 for word_0091_L4L5
# ✅ Saved slice 2 for word_0091_L4L5
# ✅ Saved slice 3 for word_0091_L4L5
# ✅ Saved slice 4 for word_0091_L4L5
# ✅ Saved slice 5 for word_0091_L4L5
# ✅ Saved slice 6 for word_0091_L4L5
# ✅ Saved slice 7 for word_0091_L4L5
# ✅ Saved slice 8 for word_0091_L4L5
# ✅ Saved slice 9 for word_0091_L4L5
# ✅ Saved slice 10 for word_0091_L4L5
# ✅ Saved slice 11 for word_0091_L4L5
# ✅ Saved slice 12 for word_0091_L4L5
# ✅ Saved slice 0 for word_0093_L4L5
# ✅ Saved slice 1 for word_0093_L4L5
# ✅ Saved slice 2 for word_0093_L4L5
# ✅ Saved slice 3 for word_0093_L4L5
# ✅ Saved slice 4 for word_0093_L4L5
# ✅ Saved slice 5 for word_0093_L4L5
# ✅ Saved slice 6 for word_0093_L4L5
# ✅ Saved slice 7 for word_0093_L4L5
# ✅ Saved slice 8 for word_0093_L4L5
# ✅ Saved slice 9 for word_0093_L4L5
# ✅ Saved slice 10 for word_0093_L4L5
# ✅ Saved slice 0 for word_0094_L4L5
# ✅ Saved slice 1 for word_0094_L4L5
# ✅ Saved slice 2 for word_0094_L4L5
# ✅ Saved slice 3 for word_0094_L4L5
# ✅ Saved slice 4 for word_0094_L4L5
# ✅ Saved slice 5 for word_0094_L4L5
# ✅ Saved slice 6 for word_0094_L4L5
# ✅ Saved slice 7 for word_0094_L4L5
# ✅ Saved slice 8 for word_0094_L4L5
# ✅ Saved slice 9 for word_0094_L4L5
# ✅ Saved slice 10 for word_0094_L4L5
# ✅ Saved slice 11 for word_0094_L4L5
# ✅ Saved slice 0 for word_0095_L4L5
# ✅ Saved slice 1 for word_0095_L4L5
# ✅ Saved slice 2 for word_0095_L4L5
# ✅ Saved slice 3 for word_0095_L4L5
# ✅ Saved slice 4 for word_0095_L4L5
# ✅ Saved slice 5 for word_0095_L4L5
# ✅ Saved slice 6 for word_0095_L4L5
# ✅ Saved slice 7 for word_0095_L4L5
# ✅ Saved slice 8 for word_0095_L4L5
# ✅ Saved slice 9 for word_0095_L4L5
# ✅ Saved slice 10 for word_0095_L4L5
# ✅ Saved slice 11 for word_0095_L4L5
# ✅ Saved slice 12 for word_0095_L4L5
# ✅ Saved slice 0 for word_0096_L4L5
# ✅ Saved slice 1 for word_0096_L4L5
# ✅ Saved slice 2 for word_0096_L4L5
# ✅ Saved slice 3 for word_0096_L4L5
# ✅ Saved slice 4 for word_0096_L4L5
# ✅ Saved slice 5 for word_0096_L4L5
# ✅ Saved slice 6 for word_0096_L4L5
# ✅ Saved slice 7 for word_0096_L4L5
# ✅ Saved slice 8 for word_0096_L4L5
# ✅ Saved slice 9 for word_0096_L4L5
# ✅ Saved slice 10 for word_0096_L4L5
# ✅ Saved slice 11 for word_0096_L4L5
# ✅ Saved slice 12 for word_0096_L4L5
# ✅ Saved slice 0 for word_0100_L4L5
# ✅ Saved slice 1 for word_0100_L4L5
# ✅ Saved slice 2 for word_0100_L4L5
# ✅ Saved slice 3 for word_0100_L4L5
# ✅ Saved slice 4 for word_0100_L4L5
# ✅ Saved slice 5 for word_0100_L4L5
# ✅ Saved slice 6 for word_0100_L4L5
# ✅ Saved slice 7 for word_0100_L4L5
# ✅ Saved slice 8 for word_0100_L4L5
# ✅ Saved slice 9 for word_0100_L4L5
# ✅ Saved slice 10 for word_0100_L4L5
# ✅ Saved slice 0 for word_0101_L4L5
# ✅ Saved slice 1 for word_0101_L4L5
# ✅ Saved slice 2 for word_0101_L4L5
# ✅ Saved slice 3 for word_0101_L4L5
# ✅ Saved slice 4 for word_0101_L4L5
# ✅ Saved slice 5 for word_0101_L4L5
# ✅ Saved slice 6 for word_0101_L4L5
# ✅ Saved slice 7 for word_0101_L4L5
# ✅ Saved slice 8 for word_0101_L4L5
# ✅ Saved slice 9 for word_0101_L4L5
# ✅ Saved slice 10 for word_0101_L4L5
# ✅ Saved slice 11 for word_0101_L4L5
# ✅ Saved slice 0 for word_0102_L4L5
# ✅ Saved slice 1 for word_0102_L4L5
# ✅ Saved slice 2 for word_0102_L4L5
# ✅ Saved slice 3 for word_0102_L4L5
# ✅ Saved slice 4 for word_0102_L4L5
# ✅ Saved slice 5 for word_0102_L4L5
# ✅ Saved slice 6 for word_0102_L4L5
# ✅ Saved slice 7 for word_0102_L4L5
# ✅ Saved slice 8 for word_0102_L4L5
# ✅ Saved slice 9 for word_0102_L4L5
# ✅ Saved slice 0 for word_0104_L4L5
# ✅ Saved slice 1 for word_0104_L4L5
# ✅ Saved slice 2 for word_0104_L4L5
# ✅ Saved slice 3 for word_0104_L4L5
# ✅ Saved slice 4 for word_0104_L4L5
# ✅ Saved slice 5 for word_0104_L4L5
# ✅ Saved slice 6 for word_0104_L4L5
# ✅ Saved slice 7 for word_0104_L4L5
# ✅ Saved slice 8 for word_0104_L4L5
# ✅ Saved slice 9 for word_0104_L4L5
# ✅ Saved slice 10 for word_0104_L4L5
# ✅ Saved slice 11 for word_0104_L4L5
# ✅ Saved slice 0 for word_0105_L4L5
# ✅ Saved slice 1 for word_0105_L4L5
# ✅ Saved slice 2 for word_0105_L4L5
# ✅ Saved slice 3 for word_0105_L4L5
# ✅ Saved slice 4 for word_0105_L4L5
# ✅ Saved slice 5 for word_0105_L4L5
# ✅ Saved slice 6 for word_0105_L4L5
# ✅ Saved slice 7 for word_0105_L4L5
# ✅ Saved slice 8 for word_0105_L4L5
# ✅ Saved slice 9 for word_0105_L4L5
# ✅ Saved slice 10 for word_0105_L4L5
# ✅ Saved slice 0 for word_0106_L4L5
# ✅ Saved slice 1 for word_0106_L4L5
# ✅ Saved slice 2 for word_0106_L4L5
# ✅ Saved slice 3 for word_0106_L4L5
# ✅ Saved slice 4 for word_0106_L4L5
# ✅ Saved slice 5 for word_0106_L4L5
# ✅ Saved slice 6 for word_0106_L4L5
# ✅ Saved slice 7 for word_0106_L4L5
# ✅ Saved slice 8 for word_0106_L4L5
# ✅ Saved slice 9 for word_0106_L4L5
# ✅ Saved slice 10 for word_0106_L4L5
# ✅ Saved slice 0 for word_0107_L4L5
# ✅ Saved slice 1 for word_0107_L4L5
# ✅ Saved slice 2 for word_0107_L4L5
# ✅ Saved slice 3 for word_0107_L4L5
# ✅ Saved slice 4 for word_0107_L4L5
# ✅ Saved slice 5 for word_0107_L4L5
# ✅ Saved slice 6 for word_0107_L4L5
# ✅ Saved slice 7 for word_0107_L4L5
# ✅ Saved slice 8 for word_0107_L4L5
# ✅ Saved slice 9 for word_0107_L4L5
# ✅ Saved slice 0 for word_0108_L4L5
# ✅ Saved slice 1 for word_0108_L4L5
# ✅ Saved slice 2 for word_0108_L4L5
# ✅ Saved slice 3 for word_0108_L4L5
# ✅ Saved slice 4 for word_0108_L4L5
# ✅ Saved slice 5 for word_0108_L4L5
# ✅ Saved slice 6 for word_0108_L4L5
# ✅ Saved slice 7 for word_0108_L4L5
# ✅ Saved slice 8 for word_0108_L4L5
# ✅ Saved slice 9 for word_0108_L4L5
# ✅ Saved slice 10 for word_0108_L4L5
# ✅ Saved slice 11 for word_0108_L4L5
# ✅ Saved slice 0 for word_0109_L4L5
# ✅ Saved slice 1 for word_0109_L4L5
# ✅ Saved slice 2 for word_0109_L4L5
# ✅ Saved slice 3 for word_0109_L4L5
# ✅ Saved slice 4 for word_0109_L4L5
# ✅ Saved slice 5 for word_0109_L4L5
# ✅ Saved slice 6 for word_0109_L4L5
# ✅ Saved slice 7 for word_0109_L4L5
# ✅ Saved slice 8 for word_0109_L4L5
# ✅ Saved slice 9 for word_0109_L4L5
# ✅ Saved slice 10 for word_0109_L4L5
# ✅ Saved slice 11 for word_0109_L4L5
# ✅ Saved slice 12 for word_0109_L4L5
# ✅ Saved slice 13 for word_0109_L4L5
# ✅ Saved slice 0 for word_0111_L4L5
# ✅ Saved slice 1 for word_0111_L4L5
# ✅ Saved slice 2 for word_0111_L4L5
# ✅ Saved slice 3 for word_0111_L4L5
# ✅ Saved slice 4 for word_0111_L4L5
# ✅ Saved slice 5 for word_0111_L4L5
# ✅ Saved slice 6 for word_0111_L4L5
# ✅ Saved slice 7 for word_0111_L4L5
# ✅ Saved slice 8 for word_0111_L4L5
# ✅ Saved slice 9 for word_0111_L4L5
# ✅ Saved slice 10 for word_0111_L4L5
# ✅ Saved slice 11 for word_0111_L4L5
# ✅ Saved slice 0 for word_0113_L4L5
# ✅ Saved slice 1 for word_0113_L4L5
# ✅ Saved slice 2 for word_0113_L4L5
# ✅ Saved slice 3 for word_0113_L4L5
# ✅ Saved slice 4 for word_0113_L4L5
# ✅ Saved slice 5 for word_0113_L4L5
# ✅ Saved slice 6 for word_0113_L4L5
# ✅ Saved slice 7 for word_0113_L4L5
# ✅ Saved slice 8 for word_0113_L4L5
# ✅ Saved slice 9 for word_0113_L4L5
# ✅ Saved slice 10 for word_0113_L4L5
# ✅ Saved slice 11 for word_0113_L4L5
# ✅ Saved slice 12 for word_0113_L4L5
# ✅ Saved slice 13 for word_0113_L4L5
# ✅ Saved slice 14 for word_0113_L4L5
# ✅ Saved slice 0 for word_0114_L4L5
# ✅ Saved slice 1 for word_0114_L4L5
# ✅ Saved slice 2 for word_0114_L4L5
# ✅ Saved slice 3 for word_0114_L4L5
# ✅ Saved slice 4 for word_0114_L4L5
# ✅ Saved slice 5 for word_0114_L4L5
# ✅ Saved slice 6 for word_0114_L4L5
# ✅ Saved slice 7 for word_0114_L4L5
# ✅ Saved slice 8 for word_0114_L4L5
# ✅ Saved slice 9 for word_0114_L4L5
# ✅ Saved slice 10 for word_0114_L4L5
# ✅ Saved slice 11 for word_0114_L4L5
# ✅ Saved slice 12 for word_0114_L4L5
# ✅ Saved slice 0 for word_0115_L4L5
# ✅ Saved slice 1 for word_0115_L4L5
# ✅ Saved slice 2 for word_0115_L4L5
# ✅ Saved slice 3 for word_0115_L4L5
# ✅ Saved slice 4 for word_0115_L4L5
# ✅ Saved slice 5 for word_0115_L4L5
# ✅ Saved slice 6 for word_0115_L4L5
# ✅ Saved slice 7 for word_0115_L4L5
# ✅ Saved slice 8 for word_0115_L4L5
# ✅ Saved slice 9 for word_0115_L4L5
# ✅ Saved slice 10 for word_0115_L4L5
# ✅ Saved slice 11 for word_0115_L4L5
# ✅ Saved slice 0 for word_0116_L4L5
# ✅ Saved slice 1 for word_0116_L4L5
# ✅ Saved slice 2 for word_0116_L4L5
# ✅ Saved slice 3 for word_0116_L4L5
# ✅ Saved slice 4 for word_0116_L4L5
# ✅ Saved slice 5 for word_0116_L4L5
# ✅ Saved slice 6 for word_0116_L4L5
# ✅ Saved slice 7 for word_0116_L4L5
# ✅ Saved slice 8 for word_0116_L4L5
# ✅ Saved slice 0 for word_0117_L4L5
# ✅ Saved slice 1 for word_0117_L4L5
# ✅ Saved slice 2 for word_0117_L4L5
# ✅ Saved slice 3 for word_0117_L4L5
# ✅ Saved slice 4 for word_0117_L4L5
# ✅ Saved slice 5 for word_0117_L4L5
# ✅ Saved slice 6 for word_0117_L4L5
# ✅ Saved slice 7 for word_0117_L4L5
# ✅ Saved slice 8 for word_0117_L4L5
# ✅ Saved slice 9 for word_0117_L4L5
# ✅ Saved slice 10 for word_0117_L4L5
# ✅ Saved slice 11 for word_0117_L4L5
# ✅ Saved slice 0 for word_0118_L4L5
# ✅ Saved slice 1 for word_0118_L4L5
# ✅ Saved slice 2 for word_0118_L4L5
# ✅ Saved slice 3 for word_0118_L4L5
# ✅ Saved slice 4 for word_0118_L4L5
# ✅ Saved slice 5 for word_0118_L4L5
# ✅ Saved slice 6 for word_0118_L4L5
# ✅ Saved slice 7 for word_0118_L4L5
# ✅ Saved slice 8 for word_0118_L4L5
# ✅ Saved slice 9 for word_0118_L4L5
# ✅ Saved slice 10 for word_0118_L4L5
# ✅ Saved slice 11 for word_0118_L4L5
# ✅ Saved slice 0 for word_0119_L4L5
# ✅ Saved slice 1 for word_0119_L4L5
# ✅ Saved slice 2 for word_0119_L4L5
# ✅ Saved slice 3 for word_0119_L4L5
# ✅ Saved slice 4 for word_0119_L4L5
# ✅ Saved slice 5 for word_0119_L4L5
# ✅ Saved slice 6 for word_0119_L4L5
# ✅ Saved slice 7 for word_0119_L4L5
# ✅ Saved slice 8 for word_0119_L4L5
# ✅ Saved slice 9 for word_0119_L4L5
# ✅ Saved slice 0 for word_0121_L4L5
# ✅ Saved slice 1 for word_0121_L4L5
# ✅ Saved slice 2 for word_0121_L4L5
# ✅ Saved slice 3 for word_0121_L4L5
# ✅ Saved slice 4 for word_0121_L4L5
# ✅ Saved slice 5 for word_0121_L4L5
# ✅ Saved slice 6 for word_0121_L4L5
# ✅ Saved slice 7 for word_0121_L4L5
# ✅ Saved slice 8 for word_0121_L4L5
# ✅ Saved slice 9 for word_0121_L4L5
# ✅ Saved slice 10 for word_0121_L4L5
# ✅ Saved slice 11 for word_0121_L4L5
# ✅ Saved slice 12 for word_0121_L4L5
# ✅ Saved slice 0 for word_0122_L4L5
# ✅ Saved slice 1 for word_0122_L4L5
# ✅ Saved slice 2 for word_0122_L4L5
# ✅ Saved slice 3 for word_0122_L4L5
# ✅ Saved slice 4 for word_0122_L4L5
# ✅ Saved slice 5 for word_0122_L4L5
# ✅ Saved slice 6 for word_0122_L4L5
# ✅ Saved slice 7 for word_0122_L4L5
# ✅ Saved slice 8 for word_0122_L4L5
# ✅ Saved slice 9 for word_0122_L4L5
# ✅ Saved slice 10 for word_0122_L4L5
# ✅ Saved slice 11 for word_0122_L4L5
# ✅ Saved slice 12 for word_0122_L4L5
# ✅ Saved slice 0 for word_0123_L4L5
# ✅ Saved slice 1 for word_0123_L4L5
# ✅ Saved slice 2 for word_0123_L4L5
# ✅ Saved slice 3 for word_0123_L4L5
# ✅ Saved slice 4 for word_0123_L4L5
# ✅ Saved slice 5 for word_0123_L4L5
# ✅ Saved slice 6 for word_0123_L4L5
# ✅ Saved slice 7 for word_0123_L4L5
# ✅ Saved slice 8 for word_0123_L4L5
# ✅ Saved slice 9 for word_0123_L4L5
# ✅ Saved slice 10 for word_0123_L4L5
# ✅ Saved slice 11 for word_0123_L4L5
# ✅ Saved slice 12 for word_0123_L4L5
# ✅ Saved slice 0 for word_0125_L4L5
# ✅ Saved slice 1 for word_0125_L4L5
# ✅ Saved slice 2 for word_0125_L4L5
# ✅ Saved slice 3 for word_0125_L4L5
# ✅ Saved slice 4 for word_0125_L4L5
# ✅ Saved slice 5 for word_0125_L4L5
# ✅ Saved slice 6 for word_0125_L4L5
# ✅ Saved slice 7 for word_0125_L4L5
# ✅ Saved slice 8 for word_0125_L4L5
# ✅ Saved slice 9 for word_0125_L4L5
# ✅ Saved slice 10 for word_0125_L4L5
# ✅ Saved slice 0 for word_0126_L4L5
# ✅ Saved slice 1 for word_0126_L4L5
# ✅ Saved slice 2 for word_0126_L4L5
# ✅ Saved slice 3 for word_0126_L4L5
# ✅ Saved slice 4 for word_0126_L4L5
# ✅ Saved slice 5 for word_0126_L4L5
# ✅ Saved slice 6 for word_0126_L4L5
# ✅ Saved slice 7 for word_0126_L4L5
# ✅ Saved slice 8 for word_0126_L4L5
# ✅ Saved slice 9 for word_0126_L4L5
# ✅ Saved slice 10 for word_0126_L4L5
# ✅ Saved slice 11 for word_0126_L4L5
# ✅ Saved slice 12 for word_0126_L4L5
# ✅ Saved slice 13 for word_0126_L4L5
# ✅ Saved slice 14 for word_0126_L4L5
# ✅ Saved slice 0 for word_0127_L4L5
# ✅ Saved slice 1 for word_0127_L4L5
# ✅ Saved slice 2 for word_0127_L4L5
# ✅ Saved slice 3 for word_0127_L4L5
# ✅ Saved slice 4 for word_0127_L4L5
# ✅ Saved slice 5 for word_0127_L4L5
# ✅ Saved slice 6 for word_0127_L4L5
# ✅ Saved slice 7 for word_0127_L4L5
# ✅ Saved slice 8 for word_0127_L4L5
# ✅ Saved slice 9 for word_0127_L4L5
# ✅ Saved slice 10 for word_0127_L4L5
# ✅ Saved slice 11 for word_0127_L4L5
# ✅ Saved slice 12 for word_0127_L4L5
# ✅ Saved slice 0 for word_0128_L4L5
# ✅ Saved slice 1 for word_0128_L4L5
# ✅ Saved slice 2 for word_0128_L4L5
# ✅ Saved slice 3 for word_0128_L4L5
# ✅ Saved slice 4 for word_0128_L4L5
# ✅ Saved slice 5 for word_0128_L4L5
# ✅ Saved slice 6 for word_0128_L4L5
# ✅ Saved slice 7 for word_0128_L4L5
# ✅ Saved slice 8 for word_0128_L4L5
# ✅ Saved slice 9 for word_0128_L4L5
# ✅ Saved slice 10 for word_0128_L4L5
# ✅ Saved slice 11 for word_0128_L4L5
# ✅ Saved slice 0 for word_0130_L4L5
# ✅ Saved slice 1 for word_0130_L4L5
# ✅ Saved slice 2 for word_0130_L4L5
# ✅ Saved slice 3 for word_0130_L4L5
# ✅ Saved slice 4 for word_0130_L4L5
# ✅ Saved slice 5 for word_0130_L4L5
# ✅ Saved slice 6 for word_0130_L4L5
# ✅ Saved slice 7 for word_0130_L4L5
# ✅ Saved slice 8 for word_0130_L4L5
# ✅ Saved slice 9 for word_0130_L4L5
# ✅ Saved slice 10 for word_0130_L4L5
# ✅ Saved slice 11 for word_0130_L4L5
# ✅ Saved slice 0 for word_0132_L4L5
# ✅ Saved slice 1 for word_0132_L4L5
# ✅ Saved slice 2 for word_0132_L4L5
# ✅ Saved slice 3 for word_0132_L4L5
# ✅ Saved slice 4 for word_0132_L4L5
# ✅ Saved slice 5 for word_0132_L4L5
# ✅ Saved slice 6 for word_0132_L4L5
# ✅ Saved slice 7 for word_0132_L4L5
# ✅ Saved slice 8 for word_0132_L4L5
# ✅ Saved slice 9 for word_0132_L4L5
# ✅ Saved slice 10 for word_0132_L4L5
# ✅ Saved slice 0 for word_0133_L4L5
# ✅ Saved slice 1 for word_0133_L4L5
# ✅ Saved slice 2 for word_0133_L4L5
# ✅ Saved slice 3 for word_0133_L4L5
# ✅ Saved slice 4 for word_0133_L4L5
# ✅ Saved slice 5 for word_0133_L4L5
# ✅ Saved slice 6 for word_0133_L4L5
# ✅ Saved slice 7 for word_0133_L4L5
# ✅ Saved slice 8 for word_0133_L4L5
# ✅ Saved slice 9 for word_0133_L4L5
# ✅ Saved slice 10 for word_0133_L4L5
# ✅ Saved slice 11 for word_0133_L4L5
# ✅ Saved slice 0 for word_0134_L4L5
# ✅ Saved slice 1 for word_0134_L4L5
# ✅ Saved slice 2 for word_0134_L4L5
# ✅ Saved slice 3 for word_0134_L4L5
# ✅ Saved slice 4 for word_0134_L4L5
# ✅ Saved slice 5 for word_0134_L4L5
# ✅ Saved slice 6 for word_0134_L4L5
# ✅ Saved slice 7 for word_0134_L4L5
# ✅ Saved slice 8 for word_0134_L4L5
# ✅ Saved slice 9 for word_0134_L4L5
# ✅ Saved slice 10 for word_0134_L4L5
# ✅ Saved slice 0 for word_0135_L4L5
# ✅ Saved slice 1 for word_0135_L4L5
# ✅ Saved slice 2 for word_0135_L4L5
# ✅ Saved slice 3 for word_0135_L4L5
# ✅ Saved slice 4 for word_0135_L4L5
# ✅ Saved slice 5 for word_0135_L4L5
# ✅ Saved slice 6 for word_0135_L4L5
# ✅ Saved slice 7 for word_0135_L4L5
# ✅ Saved slice 8 for word_0135_L4L5
# ✅ Saved slice 9 for word_0135_L4L5
# ✅ Saved slice 10 for word_0135_L4L5
# ✅ Saved slice 11 for word_0135_L4L5
# ✅ Saved slice 0 for word_0136_L4L5
# ✅ Saved slice 1 for word_0136_L4L5
# ✅ Saved slice 2 for word_0136_L4L5
# ✅ Saved slice 3 for word_0136_L4L5
# ✅ Saved slice 4 for word_0136_L4L5
# ✅ Saved slice 5 for word_0136_L4L5
# ✅ Saved slice 6 for word_0136_L4L5
# ✅ Saved slice 7 for word_0136_L4L5
# ✅ Saved slice 8 for word_0136_L4L5
# ✅ Saved slice 9 for word_0136_L4L5
# ✅ Saved slice 10 for word_0136_L4L5
# ✅ Saved slice 11 for word_0136_L4L5
# ✅ Saved slice 12 for word_0136_L4L5
# ✅ Saved slice 13 for word_0136_L4L5
# ✅ Saved slice 0 for word_0138_L4L5
# ✅ Saved slice 1 for word_0138_L4L5
# ✅ Saved slice 2 for word_0138_L4L5
# ✅ Saved slice 3 for word_0138_L4L5
# ✅ Saved slice 4 for word_0138_L4L5
# ✅ Saved slice 5 for word_0138_L4L5
# ✅ Saved slice 6 for word_0138_L4L5
# ✅ Saved slice 7 for word_0138_L4L5
# ✅ Saved slice 8 for word_0138_L4L5
# ✅ Saved slice 9 for word_0138_L4L5
# ✅ Saved slice 10 for word_0138_L4L5
# ✅ Saved slice 11 for word_0138_L4L5
# ✅ Saved slice 12 for word_0138_L4L5
# ✅ Saved slice 0 for word_0140_L4L5
# ✅ Saved slice 1 for word_0140_L4L5
# ✅ Saved slice 2 for word_0140_L4L5
# ✅ Saved slice 3 for word_0140_L4L5
# ✅ Saved slice 4 for word_0140_L4L5
# ✅ Saved slice 5 for word_0140_L4L5
# ✅ Saved slice 6 for word_0140_L4L5
# ✅ Saved slice 7 for word_0140_L4L5
# ✅ Saved slice 8 for word_0140_L4L5
# ✅ Saved slice 9 for word_0140_L4L5
# ✅ Saved slice 10 for word_0140_L4L5
# ✅ Saved slice 11 for word_0140_L4L5
# ✅ Saved slice 12 for word_0140_L4L5
# ✅ Saved slice 0 for word_0142_L4L5
# ✅ Saved slice 1 for word_0142_L4L5
# ✅ Saved slice 2 for word_0142_L4L5
# ✅ Saved slice 3 for word_0142_L4L5
# ✅ Saved slice 4 for word_0142_L4L5
# ✅ Saved slice 5 for word_0142_L4L5
# ✅ Saved slice 6 for word_0142_L4L5
# ✅ Saved slice 7 for word_0142_L4L5
# ✅ Saved slice 8 for word_0142_L4L5
# ✅ Saved slice 9 for word_0142_L4L5
# ✅ Saved slice 10 for word_0142_L4L5
# ✅ Saved slice 11 for word_0142_L4L5
# ✅ Saved slice 12 for word_0142_L4L5
# ✅ Saved slice 0 for word_0143_L4L5
# ✅ Saved slice 1 for word_0143_L4L5
# ✅ Saved slice 2 for word_0143_L4L5
# ✅ Saved slice 3 for word_0143_L4L5
# ✅ Saved slice 4 for word_0143_L4L5
# ✅ Saved slice 5 for word_0143_L4L5
# ✅ Saved slice 6 for word_0143_L4L5
# ✅ Saved slice 7 for word_0143_L4L5
# ✅ Saved slice 8 for word_0143_L4L5
# ✅ Saved slice 9 for word_0143_L4L5
# ✅ Saved slice 10 for word_0143_L4L5
# ✅ Saved slice 11 for word_0143_L4L5
# ✅ Saved slice 12 for word_0143_L4L5
# ✅ Saved slice 13 for word_0143_L4L5
# ✅ Saved slice 14 for word_0143_L4L5
# ✅ Saved slice 0 for word_0144_L4L5
# ✅ Saved slice 1 for word_0144_L4L5
# ✅ Saved slice 2 for word_0144_L4L5
# ✅ Saved slice 3 for word_0144_L4L5
# ✅ Saved slice 4 for word_0144_L4L5
# ✅ Saved slice 5 for word_0144_L4L5
# ✅ Saved slice 6 for word_0144_L4L5
# ✅ Saved slice 7 for word_0144_L4L5
# ✅ Saved slice 8 for word_0144_L4L5
# ✅ Saved slice 9 for word_0144_L4L5
# ✅ Saved slice 10 for word_0144_L4L5
# ✅ Saved slice 0 for word_0145_L4L5
# ✅ Saved slice 1 for word_0145_L4L5
# ✅ Saved slice 2 for word_0145_L4L5
# ✅ Saved slice 3 for word_0145_L4L5
# ✅ Saved slice 4 for word_0145_L4L5
# ✅ Saved slice 5 for word_0145_L4L5
# ✅ Saved slice 6 for word_0145_L4L5
# ✅ Saved slice 7 for word_0145_L4L5
# ✅ Saved slice 8 for word_0145_L4L5
# ✅ Saved slice 9 for word_0145_L4L5
# ✅ Saved slice 10 for word_0145_L4L5
# ✅ Saved slice 11 for word_0145_L4L5
# ✅ Saved slice 0 for word_0146_L4L5
# ✅ Saved slice 1 for word_0146_L4L5
# ✅ Saved slice 2 for word_0146_L4L5
# ✅ Saved slice 3 for word_0146_L4L5
# ✅ Saved slice 4 for word_0146_L4L5
# ✅ Saved slice 5 for word_0146_L4L5
# ✅ Saved slice 6 for word_0146_L4L5
# ✅ Saved slice 7 for word_0146_L4L5
# ✅ Saved slice 8 for word_0146_L4L5
# ✅ Saved slice 9 for word_0146_L4L5
# ✅ Saved slice 10 for word_0146_L4L5
# ✅ Saved slice 11 for word_0146_L4L5
# ✅ Saved slice 0 for word_0147_L4L5
# ✅ Saved slice 1 for word_0147_L4L5
# ✅ Saved slice 2 for word_0147_L4L5
# ✅ Saved slice 3 for word_0147_L4L5
# ✅ Saved slice 4 for word_0147_L4L5
# ✅ Saved slice 5 for word_0147_L4L5
# ✅ Saved slice 6 for word_0147_L4L5
# ✅ Saved slice 7 for word_0147_L4L5
# ✅ Saved slice 8 for word_0147_L4L5
# ✅ Saved slice 9 for word_0147_L4L5
# ✅ Saved slice 10 for word_0147_L4L5
# ✅ Saved slice 11 for word_0147_L4L5
# ✅ Saved slice 0 for word_0148_L4L5
# ✅ Saved slice 1 for word_0148_L4L5
# ✅ Saved slice 2 for word_0148_L4L5
# ✅ Saved slice 3 for word_0148_L4L5
# ✅ Saved slice 4 for word_0148_L4L5
# ✅ Saved slice 5 for word_0148_L4L5
# ✅ Saved slice 6 for word_0148_L4L5
# ✅ Saved slice 7 for word_0148_L4L5
# ✅ Saved slice 8 for word_0148_L4L5
# ✅ Saved slice 9 for word_0148_L4L5
# ✅ Saved slice 10 for word_0148_L4L5
# ✅ Saved slice 11 for word_0148_L4L5
# ✅ Saved slice 0 for word_0150_L4L5
# ✅ Saved slice 1 for word_0150_L4L5
# ✅ Saved slice 2 for word_0150_L4L5
# ✅ Saved slice 3 for word_0150_L4L5
# ✅ Saved slice 4 for word_0150_L4L5
# ✅ Saved slice 5 for word_0150_L4L5
# ✅ Saved slice 6 for word_0150_L4L5
# ✅ Saved slice 7 for word_0150_L4L5
# ✅ Saved slice 8 for word_0150_L4L5
# ✅ Saved slice 9 for word_0150_L4L5
# ✅ Saved slice 10 for word_0150_L4L5
# ✅ Saved slice 11 for word_0150_L4L5
# ✅ Saved slice 12 for word_0150_L4L5
# ✅ All done!
# ✅ Saved slice 0 for Jake_137
# ✅ Saved slice 1 for Jake_137
# ✅ Saved slice 2 for Jake_137
# ✅ Saved slice 3 for Jake_137
# ✅ Saved slice 4 for Jake_137
# ✅ Saved slice 5 for Jake_137
# ✅ Saved slice 6 for Jake_137
# ✅ Saved slice 7 for Jake_137
# ✅ Saved slice 8 for Jake_137
# ✅ Saved slice 9 for Jake_137
# ✅ Saved slice 10 for Jake_137
# ✅ Saved slice 11 for Jake_137
# ✅ Saved slice 12 for Jake_137
# ✅ Saved slice 13 for Jake_137
# ✅ Saved slice 0 for Jake_138
# ✅ Saved slice 1 for Jake_138
# ✅ Saved slice 2 for Jake_138
# ✅ Saved slice 3 for Jake_138
# ✅ Saved slice 4 for Jake_138
# ✅ Saved slice 5 for Jake_138
# ✅ Saved slice 6 for Jake_138
# ✅ Saved slice 7 for Jake_138
# ✅ Saved slice 8 for Jake_138
# ✅ Saved slice 9 for Jake_138
# ✅ Saved slice 10 for Jake_138
# ✅ Saved slice 11 for Jake_138
# ✅ Saved slice 12 for Jake_138
# ✅ Saved slice 13 for Jake_138
# ✅ Saved slice 0 for Jake_139
# ✅ Saved slice 1 for Jake_139
# ✅ Saved slice 2 for Jake_139
# ✅ Saved slice 3 for Jake_139
# ✅ Saved slice 4 for Jake_139
# ✅ Saved slice 5 for Jake_139
# ✅ Saved slice 6 for Jake_139
# ✅ Saved slice 7 for Jake_139
# ✅ Saved slice 8 for Jake_139
# ✅ Saved slice 9 for Jake_139
# ✅ Saved slice 10 for Jake_139
# ✅ Saved slice 11 for Jake_139
# ✅ Saved slice 12 for Jake_139
# ✅ Saved slice 0 for Jake_140
# ✅ Saved slice 1 for Jake_140
# ✅ Saved slice 2 for Jake_140
# ✅ Saved slice 3 for Jake_140
# ✅ Saved slice 4 for Jake_140
# ✅ Saved slice 5 for Jake_140
# ✅ Saved slice 6 for Jake_140
# ✅ Saved slice 7 for Jake_140
# ✅ Saved slice 8 for Jake_140
# ✅ Saved slice 9 for Jake_140
# ✅ Saved slice 10 for Jake_140
# ✅ Saved slice 11 for Jake_140
# ✅ Saved slice 0 for Jake_141
# ✅ Saved slice 1 for Jake_141
# ✅ Saved slice 2 for Jake_141
# ✅ Saved slice 3 for Jake_141
# ✅ Saved slice 4 for Jake_141
# ✅ Saved slice 5 for Jake_141
# ✅ Saved slice 6 for Jake_141
# ✅ Saved slice 7 for Jake_141
# ✅ Saved slice 8 for Jake_141
# ✅ Saved slice 9 for Jake_141
# ✅ Saved slice 10 for Jake_141
# ✅ Saved slice 11 for Jake_141
# ✅ Saved slice 12 for Jake_141
# ✅ Saved slice 0 for Jake_142
# ✅ Saved slice 1 for Jake_142
# ✅ Saved slice 2 for Jake_142
# ✅ Saved slice 3 for Jake_142
# ✅ Saved slice 4 for Jake_142
# ✅ Saved slice 5 for Jake_142
# ✅ Saved slice 6 for Jake_142
# ✅ Saved slice 7 for Jake_142
# ✅ Saved slice 8 for Jake_142
# ✅ Saved slice 9 for Jake_142
# ✅ Saved slice 10 for Jake_142
# ✅ Saved slice 11 for Jake_142
# ✅ Saved slice 12 for Jake_142
# ✅ Saved slice 13 for Jake_142
# ✅ Saved slice 0 for Jake_144
# ✅ Saved slice 1 for Jake_144
# ✅ Saved slice 2 for Jake_144
# ✅ Saved slice 3 for Jake_144
# ✅ Saved slice 4 for Jake_144
# ✅ Saved slice 5 for Jake_144
# ✅ Saved slice 6 for Jake_144
# ✅ Saved slice 7 for Jake_144
# ✅ Saved slice 8 for Jake_144
# ✅ Saved slice 9 for Jake_144
# ✅ Saved slice 10 for Jake_144
# ✅ Saved slice 11 for Jake_144
# ✅ Saved slice 12 for Jake_144
# ✅ Saved slice 13 for Jake_144
# ✅ Saved slice 0 for Jake_145
# ✅ Saved slice 1 for Jake_145
# ✅ Saved slice 2 for Jake_145
# ✅ Saved slice 3 for Jake_145
# ✅ Saved slice 4 for Jake_145
# ✅ Saved slice 5 for Jake_145
# ✅ Saved slice 6 for Jake_145
# ✅ Saved slice 7 for Jake_145
# ✅ Saved slice 8 for Jake_145
# ✅ Saved slice 9 for Jake_145
# ✅ Saved slice 10 for Jake_145
# ✅ Saved slice 11 for Jake_145
# ✅ Saved slice 12 for Jake_145
# ✅ Saved slice 0 for Jake_146
# ✅ Saved slice 1 for Jake_146
# ✅ Saved slice 2 for Jake_146
# ✅ Saved slice 3 for Jake_146
# ✅ Saved slice 4 for Jake_146
# ✅ Saved slice 5 for Jake_146
# ✅ Saved slice 6 for Jake_146
# ✅ Saved slice 7 for Jake_146
# ✅ Saved slice 8 for Jake_146
# ✅ Saved slice 9 for Jake_146
# ✅ Saved slice 10 for Jake_146
# ✅ Saved slice 11 for Jake_146
# ✅ Saved slice 12 for Jake_146
# ✅ Saved slice 13 for Jake_146
# ✅ Saved slice 0 for Jake_147
# ✅ Saved slice 1 for Jake_147
# ✅ Saved slice 2 for Jake_147
# ✅ Saved slice 3 for Jake_147
# ✅ Saved slice 4 for Jake_147
# ✅ Saved slice 5 for Jake_147
# ✅ Saved slice 6 for Jake_147
# ✅ Saved slice 7 for Jake_147
# ✅ Saved slice 8 for Jake_147
# ✅ Saved slice 9 for Jake_147
# ✅ Saved slice 10 for Jake_147
# ✅ Saved slice 11 for Jake_147
# ✅ Saved slice 12 for Jake_147
# ✅ Saved slice 0 for Jake_148
# ✅ Saved slice 1 for Jake_148
# ✅ Saved slice 2 for Jake_148
# ✅ Saved slice 3 for Jake_148
# ✅ Saved slice 4 for Jake_148
# ✅ Saved slice 5 for Jake_148
# ✅ Saved slice 6 for Jake_148
# ✅ Saved slice 7 for Jake_148
# ✅ Saved slice 8 for Jake_148
# ✅ Saved slice 9 for Jake_148
# ✅ Saved slice 10 for Jake_148
# ✅ Saved slice 11 for Jake_148
# ✅ Saved slice 12 for Jake_148
# ✅ Saved slice 13 for Jake_148
# ✅ Saved slice 0 for N_Melb_101
# ✅ Saved slice 1 for N_Melb_101
# ✅ Saved slice 2 for N_Melb_101
# ✅ Saved slice 3 for N_Melb_101
# ✅ Saved slice 4 for N_Melb_101
# ✅ Saved slice 5 for N_Melb_101
# ✅ Saved slice 6 for N_Melb_101
# ✅ Saved slice 7 for N_Melb_101
# ✅ Saved slice 8 for N_Melb_101
# ✅ Saved slice 9 for N_Melb_101
# ✅ Saved slice 10 for N_Melb_101
# ✅ Saved slice 11 for N_Melb_101
# ✅ Saved slice 12 for N_Melb_101
# ✅ Saved slice 0 for N_Melb_102
# ✅ Saved slice 1 for N_Melb_102
# ✅ Saved slice 2 for N_Melb_102
# ✅ Saved slice 3 for N_Melb_102
# ✅ Saved slice 4 for N_Melb_102
# ✅ Saved slice 5 for N_Melb_102
# ✅ Saved slice 6 for N_Melb_102
# ✅ Saved slice 7 for N_Melb_102
# ✅ Saved slice 8 for N_Melb_102
# ✅ Saved slice 9 for N_Melb_102
# ✅ Saved slice 10 for N_Melb_102
# ✅ Saved slice 11 for N_Melb_102
# ✅ Saved slice 12 for N_Melb_102
# ✅ Saved slice 13 for N_Melb_102
# ✅ Saved slice 0 for N_Melb_105
# ✅ Saved slice 1 for N_Melb_105
# ✅ Saved slice 2 for N_Melb_105
# ✅ Saved slice 3 for N_Melb_105
# ✅ Saved slice 4 for N_Melb_105
# ✅ Saved slice 5 for N_Melb_105
# ✅ Saved slice 6 for N_Melb_105
# ✅ Saved slice 7 for N_Melb_105
# ✅ Saved slice 8 for N_Melb_105
# ✅ Saved slice 9 for N_Melb_105
# ✅ Saved slice 10 for N_Melb_105
# ✅ Saved slice 11 for N_Melb_105
# ✅ Saved slice 12 for N_Melb_105
# ✅ Saved slice 13 for N_Melb_105
# ✅ Saved slice 0 for N_Melb_106
# ✅ Saved slice 1 for N_Melb_106
# ✅ Saved slice 2 for N_Melb_106
# ✅ Saved slice 3 for N_Melb_106
# ✅ Saved slice 4 for N_Melb_106
# ✅ Saved slice 5 for N_Melb_106
# ✅ Saved slice 6 for N_Melb_106
# ✅ Saved slice 7 for N_Melb_106
# ✅ Saved slice 8 for N_Melb_106
# ✅ Saved slice 9 for N_Melb_106
# ✅ Saved slice 10 for N_Melb_106
# ✅ Saved slice 11 for N_Melb_106
# ✅ Saved slice 12 for N_Melb_106
# ✅ Saved slice 13 for N_Melb_106
# ✅ Saved slice 0 for N_Melb_115
# ✅ Saved slice 1 for N_Melb_115
# ✅ Saved slice 2 for N_Melb_115
# ✅ Saved slice 3 for N_Melb_115
# ✅ Saved slice 4 for N_Melb_115
# ✅ Saved slice 5 for N_Melb_115
# ✅ Saved slice 6 for N_Melb_115
# ✅ Saved slice 7 for N_Melb_115
# ✅ Saved slice 8 for N_Melb_115
# ✅ Saved slice 9 for N_Melb_115
# ✅ Saved slice 10 for N_Melb_115
# ✅ Saved slice 11 for N_Melb_115
# ✅ Saved slice 12 for N_Melb_115
# ✅ Saved slice 13 for N_Melb_115
# ✅ Saved slice 0 for West_Bd_101
# ✅ Saved slice 1 for West_Bd_101
# ✅ Saved slice 2 for West_Bd_101
# ✅ Saved slice 3 for West_Bd_101
# ✅ Saved slice 4 for West_Bd_101
# ✅ Saved slice 5 for West_Bd_101
# ✅ Saved slice 6 for West_Bd_101
# ✅ Saved slice 7 for West_Bd_101
# ✅ Saved slice 8 for West_Bd_101
# ✅ Saved slice 9 for West_Bd_101
# ✅ Saved slice 10 for West_Bd_101
# ✅ Saved slice 11 for West_Bd_101
# ✅ Saved slice 12 for West_Bd_101
# ✅ Saved slice 0 for West_Bd_102
# ✅ Saved slice 1 for West_Bd_102
# ✅ Saved slice 2 for West_Bd_102
# ✅ Saved slice 3 for West_Bd_102
# ✅ Saved slice 4 for West_Bd_102
# ✅ Saved slice 5 for West_Bd_102
# ✅ Saved slice 6 for West_Bd_102
# ✅ Saved slice 7 for West_Bd_102
# ✅ Saved slice 8 for West_Bd_102
# ✅ Saved slice 9 for West_Bd_102
# ✅ Saved slice 10 for West_Bd_102
# ✅ Saved slice 11 for West_Bd_102
# ✅ Saved slice 12 for West_Bd_102
# ✅ Saved slice 0 for West_Bd_105
# ✅ Saved slice 1 for West_Bd_105
# ✅ Saved slice 2 for West_Bd_105
# ✅ Saved slice 3 for West_Bd_105
# ✅ Saved slice 4 for West_Bd_105
# ✅ Saved slice 5 for West_Bd_105
# ✅ Saved slice 6 for West_Bd_105
# ✅ Saved slice 7 for West_Bd_105
# ✅ Saved slice 8 for West_Bd_105
# ✅ Saved slice 9 for West_Bd_105
# ✅ Saved slice 10 for West_Bd_105
# ✅ Saved slice 11 for West_Bd_105
# ✅ Saved slice 12 for West_Bd_105
# ✅ Saved slice 0 for West_Bd_106
# ✅ Saved slice 1 for West_Bd_106
# ✅ Saved slice 2 for West_Bd_106
# ✅ Saved slice 3 for West_Bd_106
# ✅ Saved slice 4 for West_Bd_106
# ✅ Saved slice 5 for West_Bd_106
# ✅ Saved slice 6 for West_Bd_106
# ✅ Saved slice 7 for West_Bd_106
# ✅ Saved slice 8 for West_Bd_106
# ✅ Saved slice 9 for West_Bd_106
# ✅ Saved slice 10 for West_Bd_106
# ✅ Saved slice 11 for West_Bd_106
# ✅ Saved slice 0 for West_Bd_115
# ✅ Saved slice 1 for West_Bd_115
# ✅ Saved slice 2 for West_Bd_115
# ✅ Saved slice 3 for West_Bd_115
# ✅ Saved slice 4 for West_Bd_115
# ✅ Saved slice 5 for West_Bd_115
# ✅ Saved slice 6 for West_Bd_115
# ✅ Saved slice 7 for West_Bd_115
# ✅ Saved slice 8 for West_Bd_115
# ✅ Saved slice 9 for West_Bd_115
# ✅ Saved slice 10 for West_Bd_115
# ✅ Saved slice 11 for West_Bd_115
# ✅ Saved slice 12 for West_Bd_115
# ✅ All done!
